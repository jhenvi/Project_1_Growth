# %%
#Dependancies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#File to load
file_to_load ='GDPdata.csv'

#Read GDP csv file into Pandas dataframe
gdp_data= pd.read_csv(file_to_load)
gdp_data.head()
# Out:
#   REF_DATE     GEO           DGUID                  Seasonal adjustment  \
# 0  1997-01  Canada  2016A000011124  Seasonally adjusted at annual rates
# 1  1997-01  Canada  2016A000011124  Seasonally adjusted at annual rates
# 2  1997-01  Canada  2016A000011124  Seasonally adjusted at annual rates
# 3  1997-01  Canada  2016A000011124  Seasonally adjusted at annual rates
# 4  1997-01  Canada  2016A000011124  Seasonally adjusted at annual rates
#
#                    Prices  \
# 0  Chained (2012) dollars
# 1  Chained (2012) dollars
# 2  Chained (2012) dollars
# 3  Chained (2012) dollars
# 4  Chained (2012) dollars
#
#   North American Industry Classification System (NAICS)      UOM  UOM_ID  \
# 0                              All industries [T001]     Dollars      81
# 1                  Goods-producing industries [T002]     Dollars      81
# 2                Service-producing industries [T003]     Dollars      81
# 3                  Business sector industries [T004]     Dollars      81
# 4                      Business sector, goods [T005]     Dollars      81
#
#   SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE      VALUE STATUS  SYMBOL  \
# 0      millions          6  v1000000673    1.1.1.1  1151000.0    NaN     NaN
# 1      millions          6  v1000000674    1.1.1.2   393954.0    NaN     NaN
# 2      millions          6  v1000000675    1.1.1.3   756380.0    NaN     NaN
# 3      millions          6  v1000000676    1.1.1.4        NaN     ..     NaN
# 4      millions          6  v1000000677    1.1.1.5        NaN     ..     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         0
# 1         NaN         0
# 2         NaN         0
# 3         NaN         0
# 4         NaN         0

# %%
gdp_reddata = gdp_data.drop(columns=["DGUID","VECTOR", "COORDINATE", "SCALAR_FACTOR", "SCALAR_ID", "UOM", "UOM_ID", "STATUS", "SYMBOL", "TERMINATED","DECIMALS"])
gdp_reddata.head()
# Out:
#   REF_DATE     GEO                  Seasonal adjustment  \
# 0  1997-01  Canada  Seasonally adjusted at annual rates
# 1  1997-01  Canada  Seasonally adjusted at annual rates
# 2  1997-01  Canada  Seasonally adjusted at annual rates
# 3  1997-01  Canada  Seasonally adjusted at annual rates
# 4  1997-01  Canada  Seasonally adjusted at annual rates
#
#                    Prices  \
# 0  Chained (2012) dollars
# 1  Chained (2012) dollars
# 2  Chained (2012) dollars
# 3  Chained (2012) dollars
# 4  Chained (2012) dollars
#
#   North American Industry Classification System (NAICS)      VALUE
# 0                              All industries [T001]     1151000.0
# 1                  Goods-producing industries [T002]      393954.0
# 2                Service-producing industries [T003]      756380.0
# 3                  Business sector industries [T004]           NaN
# 4                      Business sector, goods [T005]           NaN

# %%
gdp_select = gdp_reddata[gdp_reddata.Prices == '2012 constant prices']
gdp_select
# Out:
#       REF_DATE     GEO                  Seasonal adjustment  \
# 287    1997-01  Canada  Seasonally adjusted at annual rates
# 288    1997-01  Canada  Seasonally adjusted at annual rates
# 289    1997-01  Canada  Seasonally adjusted at annual rates
# 290    1997-01  Canada  Seasonally adjusted at annual rates
# 291    1997-01  Canada  Seasonally adjusted at annual rates
# 292    1997-01  Canada  Seasonally adjusted at annual rates
# 293    1997-01  Canada  Seasonally adjusted at annual rates
# 294    1997-01  Canada  Seasonally adjusted at annual rates
# 295    1997-01  Canada  Seasonally adjusted at annual rates
# 296    1997-01  Canada  Seasonally adjusted at annual rates
# 297    1997-01  Canada  Seasonally adjusted at annual rates
# 298    1997-01  Canada  Seasonally adjusted at annual rates
# 299    1997-01  Canada  Seasonally adjusted at annual rates
# 300    1997-01  Canada  Seasonally adjusted at annual rates
# 301    1997-01  Canada  Seasonally adjusted at annual rates
# 302    1997-01  Canada  Seasonally adjusted at annual rates
# 303    1997-01  Canada  Seasonally adjusted at annual rates
# 304    1997-01  Canada  Seasonally adjusted at annual rates
# 305    1997-01  Canada  Seasonally adjusted at annual rates
# 306    1997-01  Canada  Seasonally adjusted at annual rates
# 307    1997-01  Canada  Seasonally adjusted at annual rates
# 308    1997-01  Canada  Seasonally adjusted at annual rates
# 309    1997-01  Canada  Seasonally adjusted at annual rates
# 310    1997-01  Canada  Seasonally adjusted at annual rates
# 311    1997-01  Canada  Seasonally adjusted at annual rates
# 312    1997-01  Canada  Seasonally adjusted at annual rates
# 313    1997-01  Canada  Seasonally adjusted at annual rates
# 314    1997-01  Canada  Seasonally adjusted at annual rates
# 315    1997-01  Canada  Seasonally adjusted at annual rates
# 316    1997-01  Canada  Seasonally adjusted at annual rates
# ...        ...     ...                                  ...
# 77460  2019-04  Canada                 Trading-day adjusted
# 77461  2019-04  Canada                 Trading-day adjusted
# 77462  2019-04  Canada                 Trading-day adjusted
# 77463  2019-04  Canada                 Trading-day adjusted
# 77464  2019-04  Canada                 Trading-day adjusted
# 77465  2019-04  Canada                 Trading-day adjusted
# 77466  2019-04  Canada                 Trading-day adjusted
# 77467  2019-04  Canada                 Trading-day adjusted
# 77468  2019-04  Canada                 Trading-day adjusted
# 77469  2019-04  Canada                 Trading-day adjusted
# 77470  2019-04  Canada                 Trading-day adjusted
# 77471  2019-04  Canada                 Trading-day adjusted
# 77472  2019-04  Canada                 Trading-day adjusted
# 77473  2019-04  Canada                 Trading-day adjusted
# 77474  2019-04  Canada                 Trading-day adjusted
# 77475  2019-04  Canada                 Trading-day adjusted
# 77476  2019-04  Canada                 Trading-day adjusted
# 77477  2019-04  Canada                 Trading-day adjusted
# 77478  2019-04  Canada                 Trading-day adjusted
# 77479  2019-04  Canada                 Trading-day adjusted
# 77480  2019-04  Canada                 Trading-day adjusted
# 77481  2019-04  Canada                 Trading-day adjusted
# 77482  2019-04  Canada                 Trading-day adjusted
# 77483  2019-04  Canada                 Trading-day adjusted
# 77484  2019-04  Canada                 Trading-day adjusted
# 77485  2019-04  Canada                 Trading-day adjusted
# 77486  2019-04  Canada                 Trading-day adjusted
# 77487  2019-04  Canada                 Trading-day adjusted
# 77488  2019-04  Canada                 Trading-day adjusted
# 77489  2019-04  Canada                 Trading-day adjusted
#
#                      Prices  \
# 287    2012 constant prices
# 288    2012 constant prices
# 289    2012 constant prices
# 290    2012 constant prices
# 291    2012 constant prices
# 292    2012 constant prices
# 293    2012 constant prices
# 294    2012 constant prices
# 295    2012 constant prices
# 296    2012 constant prices
# 297    2012 constant prices
# 298    2012 constant prices
# 299    2012 constant prices
# 300    2012 constant prices
# 301    2012 constant prices
# 302    2012 constant prices
# 303    2012 constant prices
# 304    2012 constant prices
# 305    2012 constant prices
# 306    2012 constant prices
# 307    2012 constant prices
# 308    2012 constant prices
# 309    2012 constant prices
# 310    2012 constant prices
# 311    2012 constant prices
# 312    2012 constant prices
# 313    2012 constant prices
# 314    2012 constant prices
# 315    2012 constant prices
# 316    2012 constant prices
# ...                     ...
# 77460  2012 constant prices
# 77461  2012 constant prices
# 77462  2012 constant prices
# 77463  2012 constant prices
# 77464  2012 constant prices
# 77465  2012 constant prices
# 77466  2012 constant prices
# 77467  2012 constant prices
# 77468  2012 constant prices
# 77469  2012 constant prices
# 77470  2012 constant prices
# 77471  2012 constant prices
# 77472  2012 constant prices
# 77473  2012 constant prices
# 77474  2012 constant prices
# 77475  2012 constant prices
# 77476  2012 constant prices
# 77477  2012 constant prices
# 77478  2012 constant prices
# 77479  2012 constant prices
# 77480  2012 constant prices
# 77481  2012 constant prices
# 77482  2012 constant prices
# 77483  2012 constant prices
# 77484  2012 constant prices
# 77485  2012 constant prices
# 77486  2012 constant prices
# 77487  2012 constant prices
# 77488  2012 constant prices
# 77489  2012 constant prices
#
#       North American Industry Classification System (NAICS)      VALUE
# 287                                All industries [T001]     1166100.0
# 288                    Goods-producing industries [T002]      404599.0
# 289                  Service-producing industries [T003]      759706.0
# 290                    Business sector industries [T004]           NaN
# 291                        Business sector, goods [T005]           NaN
# 292                     Business sector, services [T006]           NaN
# 293                Non-business sector industries [T007]           NaN
# 294                    Non-business sector, goods [T008]           NaN
# 295                 Non-business sector, services [T009]           NaN
# 296                         Industrial production [T010]      303011.0
# 297          Non-durable manufacturing industries [T011]       84203.0
# 298              Durable manufacturing industries [T012]       87834.0
# 299    Information and communication technology secto...           NaN
# 300    Information and communication technology, manu...           NaN
# 301    Information and communication technology, serv...           NaN
# 302                                 Energy sector [T016]      136387.0
# 303       Industrial production (1950 definition) [T017]           NaN
# 304                                 Public Sector [T018]           NaN
# 305                      Content and media sector [T019]           NaN
# 306       All industries (except cannabis sector) [T020]     1164806.0
# 307                               Cannabis sector [T021]        2207.0
# 308                    Cannabis sector (licensed) [T022]           0.0
# 309                  Cannabis sector (unlicensed) [T023]        2207.0
# 310    All industries (except unlicensed cannabis sec...     1164806.0
# 311      Agriculture, forestry, fishing and hunting [11]       25071.0
# 312                     Crop and animal production [11A]       17384.0
# 313                                Crop production [111]       13504.0
# 314             Crop production (except cannabis) [111X]       13113.0
# 315                           Cannabis production [111C]        1449.0
# 316               Cannabis production (licensed) [111CL]           0.0
# ...                                                  ...           ...
# 77460            Elementary and secondary schools [6111]       16348.0
# 77461          Community colleges and C.E.G.E.P.s [6112]        2205.0
# 77462                                Universities [6113]        8866.0
# 77463                  Other educational services [611A]        1235.0
# 77464             Health care and social assistance [62]       34642.0
# 77465              Ambulatory health care services [621]       13598.0
# 77466                                    Hospitals [622]       12199.0
# 77467      Nursing and residential care facilities [623]        4978.0
# 77468                            Social Assistance [624]        3867.0
# 77469                                  Health care [62X]       30775.0
# 77470            Arts, entertainment and recreation [71]        3758.0
# 77471  Performing arts, spectator sports and related ...        1733.0
# 77472  Amusement, gambling and recreation industries ...        2025.0
# 77473                         Gambling industries [7132]         580.0
# 77474         Amusement and recreation industries [713A]        1445.0
# 77475               Accommodation and food services [72]       11512.0
# 77476                       Accommodation services [721]        3414.0
# 77477            Food services and drinking places [722]        8098.0
# 77478  Other services (except public administration) ...        9787.0
# 77479                       Repair and maintenance [811]        3731.0
# 77480                Personal and laundry services [812]        2142.0
# 77481  Religious, grant-making, civic, and profession...        3147.0
# 77482                           Private households [814]         767.0
# 77483                         Public administration [91]       33791.0
# 77484     Federal government public administration [911]       12650.0
# 77485                            Defence services [9111]        3192.0
# 77486  Federal government public administration (exce...        9458.0
# 77487  Provincial and territorial public administrati...        9066.0
# 77488  Local, municipal and regional public administr...       11002.0
# 77489             Aboriginal public administration [914]        1073.0
#
# [51660 rows x 6 columns]

# %%
gdp_select2 = gdp_select[gdp_reddata['Seasonal adjustment'] == 'Seasonally adjusted at annual rates']
gdp_select2
# Out:
# C:\Users\danbo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       REF_DATE     GEO                  Seasonal adjustment  \
# 287    1997-01  Canada  Seasonally adjusted at annual rates
# 288    1997-01  Canada  Seasonally adjusted at annual rates
# 289    1997-01  Canada  Seasonally adjusted at annual rates
# 290    1997-01  Canada  Seasonally adjusted at annual rates
# 291    1997-01  Canada  Seasonally adjusted at annual rates
# 292    1997-01  Canada  Seasonally adjusted at annual rates
# 293    1997-01  Canada  Seasonally adjusted at annual rates
# 294    1997-01  Canada  Seasonally adjusted at annual rates
# 295    1997-01  Canada  Seasonally adjusted at annual rates
# 296    1997-01  Canada  Seasonally adjusted at annual rates
# 297    1997-01  Canada  Seasonally adjusted at annual rates
# 298    1997-01  Canada  Seasonally adjusted at annual rates
# 299    1997-01  Canada  Seasonally adjusted at annual rates
# 300    1997-01  Canada  Seasonally adjusted at annual rates
# 301    1997-01  Canada  Seasonally adjusted at annual rates
# 302    1997-01  Canada  Seasonally adjusted at annual rates
# 303    1997-01  Canada  Seasonally adjusted at annual rates
# 304    1997-01  Canada  Seasonally adjusted at annual rates
# 305    1997-01  Canada  Seasonally adjusted at annual rates
# 306    1997-01  Canada  Seasonally adjusted at annual rates
# 307    1997-01  Canada  Seasonally adjusted at annual rates
# 308    1997-01  Canada  Seasonally adjusted at annual rates
# 309    1997-01  Canada  Seasonally adjusted at annual rates
# 310    1997-01  Canada  Seasonally adjusted at annual rates
# 311    1997-01  Canada  Seasonally adjusted at annual rates
# 312    1997-01  Canada  Seasonally adjusted at annual rates
# 313    1997-01  Canada  Seasonally adjusted at annual rates
# 314    1997-01  Canada  Seasonally adjusted at annual rates
# 315    1997-01  Canada  Seasonally adjusted at annual rates
# 316    1997-01  Canada  Seasonally adjusted at annual rates
# ...        ...     ...                                  ...
# 77173  2019-04  Canada  Seasonally adjusted at annual rates
# 77174  2019-04  Canada  Seasonally adjusted at annual rates
# 77175  2019-04  Canada  Seasonally adjusted at annual rates
# 77176  2019-04  Canada  Seasonally adjusted at annual rates
# 77177  2019-04  Canada  Seasonally adjusted at annual rates
# 77178  2019-04  Canada  Seasonally adjusted at annual rates
# 77179  2019-04  Canada  Seasonally adjusted at annual rates
# 77180  2019-04  Canada  Seasonally adjusted at annual rates
# 77181  2019-04  Canada  Seasonally adjusted at annual rates
# 77182  2019-04  Canada  Seasonally adjusted at annual rates
# 77183  2019-04  Canada  Seasonally adjusted at annual rates
# 77184  2019-04  Canada  Seasonally adjusted at annual rates
# 77185  2019-04  Canada  Seasonally adjusted at annual rates
# 77186  2019-04  Canada  Seasonally adjusted at annual rates
# 77187  2019-04  Canada  Seasonally adjusted at annual rates
# 77188  2019-04  Canada  Seasonally adjusted at annual rates
# 77189  2019-04  Canada  Seasonally adjusted at annual rates
# 77190  2019-04  Canada  Seasonally adjusted at annual rates
# 77191  2019-04  Canada  Seasonally adjusted at annual rates
# 77192  2019-04  Canada  Seasonally adjusted at annual rates
# 77193  2019-04  Canada  Seasonally adjusted at annual rates
# 77194  2019-04  Canada  Seasonally adjusted at annual rates
# 77195  2019-04  Canada  Seasonally adjusted at annual rates
# 77196  2019-04  Canada  Seasonally adjusted at annual rates
# 77197  2019-04  Canada  Seasonally adjusted at annual rates
# 77198  2019-04  Canada  Seasonally adjusted at annual rates
# 77199  2019-04  Canada  Seasonally adjusted at annual rates
# 77200  2019-04  Canada  Seasonally adjusted at annual rates
# 77201  2019-04  Canada  Seasonally adjusted at annual rates
# 77202  2019-04  Canada  Seasonally adjusted at annual rates
#
#                      Prices  \
# 287    2012 constant prices
# 288    2012 constant prices
# 289    2012 constant prices
# 290    2012 constant prices
# 291    2012 constant prices
# 292    2012 constant prices
# 293    2012 constant prices
# 294    2012 constant prices
# 295    2012 constant prices
# 296    2012 constant prices
# 297    2012 constant prices
# 298    2012 constant prices
# 299    2012 constant prices
# 300    2012 constant prices
# 301    2012 constant prices
# 302    2012 constant prices
# 303    2012 constant prices
# 304    2012 constant prices
# 305    2012 constant prices
# 306    2012 constant prices
# 307    2012 constant prices
# 308    2012 constant prices
# 309    2012 constant prices
# 310    2012 constant prices
# 311    2012 constant prices
# 312    2012 constant prices
# 313    2012 constant prices
# 314    2012 constant prices
# 315    2012 constant prices
# 316    2012 constant prices
# ...                     ...
# 77173  2012 constant prices
# 77174  2012 constant prices
# 77175  2012 constant prices
# 77176  2012 constant prices
# 77177  2012 constant prices
# 77178  2012 constant prices
# 77179  2012 constant prices
# 77180  2012 constant prices
# 77181  2012 constant prices
# 77182  2012 constant prices
# 77183  2012 constant prices
# 77184  2012 constant prices
# 77185  2012 constant prices
# 77186  2012 constant prices
# 77187  2012 constant prices
# 77188  2012 constant prices
# 77189  2012 constant prices
# 77190  2012 constant prices
# 77191  2012 constant prices
# 77192  2012 constant prices
# 77193  2012 constant prices
# 77194  2012 constant prices
# 77195  2012 constant prices
# 77196  2012 constant prices
# 77197  2012 constant prices
# 77198  2012 constant prices
# 77199  2012 constant prices
# 77200  2012 constant prices
# 77201  2012 constant prices
# 77202  2012 constant prices
#
#       North American Industry Classification System (NAICS)      VALUE
# 287                                All industries [T001]     1166100.0
# 288                    Goods-producing industries [T002]      404599.0
# 289                  Service-producing industries [T003]      759706.0
# 290                    Business sector industries [T004]           NaN
# 291                        Business sector, goods [T005]           NaN
# 292                     Business sector, services [T006]           NaN
# 293                Non-business sector industries [T007]           NaN
# 294                    Non-business sector, goods [T008]           NaN
# 295                 Non-business sector, services [T009]           NaN
# 296                         Industrial production [T010]      303011.0
# 297          Non-durable manufacturing industries [T011]       84203.0
# 298              Durable manufacturing industries [T012]       87834.0
# 299    Information and communication technology secto...           NaN
# 300    Information and communication technology, manu...           NaN
# 301    Information and communication technology, serv...           NaN
# 302                                 Energy sector [T016]      136387.0
# 303       Industrial production (1950 definition) [T017]           NaN
# 304                                 Public Sector [T018]           NaN
# 305                      Content and media sector [T019]           NaN
# 306       All industries (except cannabis sector) [T020]     1164806.0
# 307                               Cannabis sector [T021]        2207.0
# 308                    Cannabis sector (licensed) [T022]           0.0
# 309                  Cannabis sector (unlicensed) [T023]        2207.0
# 310    All industries (except unlicensed cannabis sec...     1164806.0
# 311      Agriculture, forestry, fishing and hunting [11]       25071.0
# 312                     Crop and animal production [11A]       17384.0
# 313                                Crop production [111]       13504.0
# 314             Crop production (except cannabis) [111X]       13113.0
# 315                           Cannabis production [111C]        1449.0
# 316               Cannabis production (licensed) [111CL]           0.0
# ...                                                  ...           ...
# 77173            Elementary and secondary schools [6111]       57057.0
# 77174          Community colleges and C.E.G.E.P.s [6112]        8516.0
# 77175                                Universities [6113]       35370.0
# 77176                  Other educational services [611A]        4848.0
# 77177             Health care and social assistance [62]      138325.0
# 77178              Ambulatory health care services [621]       54465.0
# 77179                                    Hospitals [622]       48464.0
# 77180      Nursing and residential care facilities [623]       19977.0
# 77181                            Social Assistance [624]       15419.0
# 77182                                  Health care [62X]      122906.0
# 77183            Arts, entertainment and recreation [71]       15454.0
# 77184  Performing arts, spectator sports and related ...        7453.0
# 77185  Amusement, gambling and recreation industries ...        8001.0
# 77186                         Gambling industries [7132]        2342.0
# 77187         Amusement and recreation industries [713A]        5659.0
# 77188               Accommodation and food services [72]       44843.0
# 77189                       Accommodation services [721]       13301.0
# 77190            Food services and drinking places [722]       31543.0
# 77191  Other services (except public administration) ...       38278.0
# 77192                       Repair and maintenance [811]       14221.0
# 77193                Personal and laundry services [812]        8442.0
# 77194  Religious, grant-making, civic, and profession...       12597.0
# 77195                           Private households [814]        3017.0
# 77196                         Public administration [91]      132004.0
# 77197     Federal government public administration [911]       49322.0
# 77198                            Defence services [9111]       12736.0
# 77199  Federal government public administration (exce...       36586.0
# 77200  Provincial and territorial public administrati...       35194.0
# 77201  Local, municipal and regional public administr...       43148.0
# 77202             Aboriginal public administration [914]        4341.0
#
# [25830 rows x 6 columns]

# %%
gdp_select3 = gdp_select2[gdp_reddata['GEO'] == 'Canada']
gdp_select3
# Out:
# C:\Users\danbo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       REF_DATE     GEO                  Seasonal adjustment  \
# 287    1997-01  Canada  Seasonally adjusted at annual rates
# 288    1997-01  Canada  Seasonally adjusted at annual rates
# 289    1997-01  Canada  Seasonally adjusted at annual rates
# 290    1997-01  Canada  Seasonally adjusted at annual rates
# 291    1997-01  Canada  Seasonally adjusted at annual rates
# 292    1997-01  Canada  Seasonally adjusted at annual rates
# 293    1997-01  Canada  Seasonally adjusted at annual rates
# 294    1997-01  Canada  Seasonally adjusted at annual rates
# 295    1997-01  Canada  Seasonally adjusted at annual rates
# 296    1997-01  Canada  Seasonally adjusted at annual rates
# 297    1997-01  Canada  Seasonally adjusted at annual rates
# 298    1997-01  Canada  Seasonally adjusted at annual rates
# 299    1997-01  Canada  Seasonally adjusted at annual rates
# 300    1997-01  Canada  Seasonally adjusted at annual rates
# 301    1997-01  Canada  Seasonally adjusted at annual rates
# 302    1997-01  Canada  Seasonally adjusted at annual rates
# 303    1997-01  Canada  Seasonally adjusted at annual rates
# 304    1997-01  Canada  Seasonally adjusted at annual rates
# 305    1997-01  Canada  Seasonally adjusted at annual rates
# 306    1997-01  Canada  Seasonally adjusted at annual rates
# 307    1997-01  Canada  Seasonally adjusted at annual rates
# 308    1997-01  Canada  Seasonally adjusted at annual rates
# 309    1997-01  Canada  Seasonally adjusted at annual rates
# 310    1997-01  Canada  Seasonally adjusted at annual rates
# 311    1997-01  Canada  Seasonally adjusted at annual rates
# 312    1997-01  Canada  Seasonally adjusted at annual rates
# 313    1997-01  Canada  Seasonally adjusted at annual rates
# 314    1997-01  Canada  Seasonally adjusted at annual rates
# 315    1997-01  Canada  Seasonally adjusted at annual rates
# 316    1997-01  Canada  Seasonally adjusted at annual rates
# ...        ...     ...                                  ...
# 77173  2019-04  Canada  Seasonally adjusted at annual rates
# 77174  2019-04  Canada  Seasonally adjusted at annual rates
# 77175  2019-04  Canada  Seasonally adjusted at annual rates
# 77176  2019-04  Canada  Seasonally adjusted at annual rates
# 77177  2019-04  Canada  Seasonally adjusted at annual rates
# 77178  2019-04  Canada  Seasonally adjusted at annual rates
# 77179  2019-04  Canada  Seasonally adjusted at annual rates
# 77180  2019-04  Canada  Seasonally adjusted at annual rates
# 77181  2019-04  Canada  Seasonally adjusted at annual rates
# 77182  2019-04  Canada  Seasonally adjusted at annual rates
# 77183  2019-04  Canada  Seasonally adjusted at annual rates
# 77184  2019-04  Canada  Seasonally adjusted at annual rates
# 77185  2019-04  Canada  Seasonally adjusted at annual rates
# 77186  2019-04  Canada  Seasonally adjusted at annual rates
# 77187  2019-04  Canada  Seasonally adjusted at annual rates
# 77188  2019-04  Canada  Seasonally adjusted at annual rates
# 77189  2019-04  Canada  Seasonally adjusted at annual rates
# 77190  2019-04  Canada  Seasonally adjusted at annual rates
# 77191  2019-04  Canada  Seasonally adjusted at annual rates
# 77192  2019-04  Canada  Seasonally adjusted at annual rates
# 77193  2019-04  Canada  Seasonally adjusted at annual rates
# 77194  2019-04  Canada  Seasonally adjusted at annual rates
# 77195  2019-04  Canada  Seasonally adjusted at annual rates
# 77196  2019-04  Canada  Seasonally adjusted at annual rates
# 77197  2019-04  Canada  Seasonally adjusted at annual rates
# 77198  2019-04  Canada  Seasonally adjusted at annual rates
# 77199  2019-04  Canada  Seasonally adjusted at annual rates
# 77200  2019-04  Canada  Seasonally adjusted at annual rates
# 77201  2019-04  Canada  Seasonally adjusted at annual rates
# 77202  2019-04  Canada  Seasonally adjusted at annual rates
#
#                      Prices  \
# 287    2012 constant prices
# 288    2012 constant prices
# 289    2012 constant prices
# 290    2012 constant prices
# 291    2012 constant prices
# 292    2012 constant prices
# 293    2012 constant prices
# 294    2012 constant prices
# 295    2012 constant prices
# 296    2012 constant prices
# 297    2012 constant prices
# 298    2012 constant prices
# 299    2012 constant prices
# 300    2012 constant prices
# 301    2012 constant prices
# 302    2012 constant prices
# 303    2012 constant prices
# 304    2012 constant prices
# 305    2012 constant prices
# 306    2012 constant prices
# 307    2012 constant prices
# 308    2012 constant prices
# 309    2012 constant prices
# 310    2012 constant prices
# 311    2012 constant prices
# 312    2012 constant prices
# 313    2012 constant prices
# 314    2012 constant prices
# 315    2012 constant prices
# 316    2012 constant prices
# ...                     ...
# 77173  2012 constant prices
# 77174  2012 constant prices
# 77175  2012 constant prices
# 77176  2012 constant prices
# 77177  2012 constant prices
# 77178  2012 constant prices
# 77179  2012 constant prices
# 77180  2012 constant prices
# 77181  2012 constant prices
# 77182  2012 constant prices
# 77183  2012 constant prices
# 77184  2012 constant prices
# 77185  2012 constant prices
# 77186  2012 constant prices
# 77187  2012 constant prices
# 77188  2012 constant prices
# 77189  2012 constant prices
# 77190  2012 constant prices
# 77191  2012 constant prices
# 77192  2012 constant prices
# 77193  2012 constant prices
# 77194  2012 constant prices
# 77195  2012 constant prices
# 77196  2012 constant prices
# 77197  2012 constant prices
# 77198  2012 constant prices
# 77199  2012 constant prices
# 77200  2012 constant prices
# 77201  2012 constant prices
# 77202  2012 constant prices
#
#       North American Industry Classification System (NAICS)      VALUE
# 287                                All industries [T001]     1166100.0
# 288                    Goods-producing industries [T002]      404599.0
# 289                  Service-producing industries [T003]      759706.0
# 290                    Business sector industries [T004]           NaN
# 291                        Business sector, goods [T005]           NaN
# 292                     Business sector, services [T006]           NaN
# 293                Non-business sector industries [T007]           NaN
# 294                    Non-business sector, goods [T008]           NaN
# 295                 Non-business sector, services [T009]           NaN
# 296                         Industrial production [T010]      303011.0
# 297          Non-durable manufacturing industries [T011]       84203.0
# 298              Durable manufacturing industries [T012]       87834.0
# 299    Information and communication technology secto...           NaN
# 300    Information and communication technology, manu...           NaN
# 301    Information and communication technology, serv...           NaN
# 302                                 Energy sector [T016]      136387.0
# 303       Industrial production (1950 definition) [T017]           NaN
# 304                                 Public Sector [T018]           NaN
# 305                      Content and media sector [T019]           NaN
# 306       All industries (except cannabis sector) [T020]     1164806.0
# 307                               Cannabis sector [T021]        2207.0
# 308                    Cannabis sector (licensed) [T022]           0.0
# 309                  Cannabis sector (unlicensed) [T023]        2207.0
# 310    All industries (except unlicensed cannabis sec...     1164806.0
# 311      Agriculture, forestry, fishing and hunting [11]       25071.0
# 312                     Crop and animal production [11A]       17384.0
# 313                                Crop production [111]       13504.0
# 314             Crop production (except cannabis) [111X]       13113.0
# 315                           Cannabis production [111C]        1449.0
# 316               Cannabis production (licensed) [111CL]           0.0
# ...                                                  ...           ...
# 77173            Elementary and secondary schools [6111]       57057.0
# 77174          Community colleges and C.E.G.E.P.s [6112]        8516.0
# 77175                                Universities [6113]       35370.0
# 77176                  Other educational services [611A]        4848.0
# 77177             Health care and social assistance [62]      138325.0
# 77178              Ambulatory health care services [621]       54465.0
# 77179                                    Hospitals [622]       48464.0
# 77180      Nursing and residential care facilities [623]       19977.0
# 77181                            Social Assistance [624]       15419.0
# 77182                                  Health care [62X]      122906.0
# 77183            Arts, entertainment and recreation [71]       15454.0
# 77184  Performing arts, spectator sports and related ...        7453.0
# 77185  Amusement, gambling and recreation industries ...        8001.0
# 77186                         Gambling industries [7132]        2342.0
# 77187         Amusement and recreation industries [713A]        5659.0
# 77188               Accommodation and food services [72]       44843.0
# 77189                       Accommodation services [721]       13301.0
# 77190            Food services and drinking places [722]       31543.0
# 77191  Other services (except public administration) ...       38278.0
# 77192                       Repair and maintenance [811]       14221.0
# 77193                Personal and laundry services [812]        8442.0
# 77194  Religious, grant-making, civic, and profession...       12597.0
# 77195                           Private households [814]        3017.0
# 77196                         Public administration [91]      132004.0
# 77197     Federal government public administration [911]       49322.0
# 77198                            Defence services [9111]       12736.0
# 77199  Federal government public administration (exce...       36586.0
# 77200  Provincial and territorial public administrati...       35194.0
# 77201  Local, municipal and regional public administr...       43148.0
# 77202             Aboriginal public administration [914]        4341.0
#
# [25830 rows x 6 columns]

# %%
gdp_select4 = gdp_select2[gdp_reddata['North American Industry Classification System (NAICS)'] == 'Information and communication technology sector [T013]']
gdp_select4a = gdp_select4.dropna()
gdp_select4a.head()
# Out:
# C:\Users\danbo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       REF_DATE     GEO                  Seasonal adjustment  \
# 34739  2007-01  Canada  Seasonally adjusted at annual rates
# 35600  2007-04  Canada  Seasonally adjusted at annual rates
# 36461  2007-07  Canada  Seasonally adjusted at annual rates
# 37322  2007-10  Canada  Seasonally adjusted at annual rates
# 38183  2008-01  Canada  Seasonally adjusted at annual rates
#
#                      Prices  \
# 34739  2012 constant prices
# 35600  2012 constant prices
# 36461  2012 constant prices
# 37322  2012 constant prices
# 38183  2012 constant prices
#
#       North American Industry Classification System (NAICS)    VALUE
# 34739  Information and communication technology secto...     67836.0
# 35600  Information and communication technology secto...     68254.0
# 36461  Information and communication technology secto...     68894.0
# 37322  Information and communication technology secto...     68718.0
# 38183  Information and communication technology secto...     69434.0

# %%
# Reduce the selected data frame to Q1 data only. ie take the -01 entry for each year as the annual number

date=[]
geo=[]
season_adj=[]
prices=[]
naics=[]
gdpvalue=[]

i=0
for i in range(0, len(gdp_select4a)-3, 4):
for city in cities:
    response=requests.get(query_url+city).json()
    i=i+1

    try:
        date.append(gdp_select4a[i]['REF_DATE'])
        geo.append(gdp_select4a[i]['GEO'])
        season_adj.append(gdp_select4a[i]['Seasonal adjustment'])
        prices.append(gdp_select4a[i]['Prices'])
        naics.append(gdp_select4a[i]['North American Industry Classification System (NAICS)'])
        gdpvalue.append(gdp_select4a[i]['Value'])
       
    except KeyError:
        pass

# %%
# Minor Data Munging to Re-Format the Data Frames
reformated_gdp_select4a =gdp_select4a.pivot(index='REF_DATE', columns='North American Industry Classification System (NAICS)', values='VALUE')

# Preview that Reformatting worked
reformated_gdp_select4a.head()
# Out:
# North American Industry Classification System (NAICS)  Information and communication technology sector [T013]
# REF_DATE
# 2007-01                                                                                          67836.0
# 2007-04                                                                                          68254.0
# 2007-07                                                                                          68894.0
# 2007-10                                                                                          68718.0
# 2008-01                                                                                          69434.0

# %%
# Generate the Plot
chart_df = reformated_gdp_select4a

time= chart_df.index
indust1 = chart_df['Information and communication technology sector [T013]']


#Plot drug mean series
plt.plot(time,indust1, label ='Information and communication technology sector [T013]', marker = 'o', ls=':', color='red')


#Format Chart

plt.title("GDP by Quarter")
plt.ylabel("Dollars ($ millions)")
plt.xlabel("Time (Quarters)")
plt.grid(b=True, which='major', axis = 'y', color='#666666', linestyle='-')
plt.legend(loc=0)

# Save the Figure
plt.savefig("GDP by quarter 2007to 2019.png")

#Show the Figure
plt.show()
#plt.tight_layout()
