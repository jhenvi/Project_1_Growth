# %%
# %matplotlib notebook

# %%
# %run main.ipynb
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# %run gdp_analysisv2.ipynb
# Out:
# gdp_analysisv2.ipynb:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   {
# gdp_analysisv2.ipynb:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   {
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
# %run Project1JV_2.ipynb
