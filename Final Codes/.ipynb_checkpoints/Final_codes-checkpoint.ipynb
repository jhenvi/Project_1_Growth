# %%
# %matplotlib notebook

# %%
# %run main.ipynb
# Out:
# ERROR:root:File `'main.ipynb.py'` not found.

# %%
# %run gdp_analysisv2.ipynb
# Out:
# No handles with labels found to put in legend.

# %%
# %run Project1JV_2.ipynb
